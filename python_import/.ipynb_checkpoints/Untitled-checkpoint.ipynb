# %%
import pandas as pd
import requests

# %%
df = pd.read_excel("data.xlsx",sheet_name="rajony_nádoby")
df['lat'] = 0
df['long'] = 0

# %%
def getGeoData(row):
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    querystring = {"address":"Kôstková30,BratislavaCA","key":"AIzaSyCp5_r8YXqn1XFa589X1hpumAogDcJ7I4Q"}
    payload = ""
    response = requests.request("GET", url, data=payload, params=querystring)

# %%
df = df.apply(lambda row: getGeoData(row), axis=1)

# %%
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    querystring = {"address":"Kôstková30,BratislavaCA","key":"AIzaSyCp5_r8YXqn1XFa589X1hpumAogDcJ7I4Q"}
    payload = ""
    response = requests.request("GET", url, data=payload, params=querystring)
# Out:
#         Objem Materiál nádoby     KU - městská část KU - městský obvod  \
# 0         NaN             NaN                   NaN                NaN
# 1       240 l           Plast               Jarovce       Bratislava 5
# 2       120 l           Plast                  Rača       Bratislava 3
# 3       240 l           Plast               Rusovce       Bratislava 5
# 4       240 l           Plast           Staré Mesto       Bratislava 1
# ...       ...             ...                   ...                ...
# 90572  1100 l           Plech               Ružinov       Bratislava 2
# 90573   120 l           Plast  Podunajské Biskupice       Bratislava 2
# 90574   240 l           Plast            Nové Mesto       Bratislava 3
# 90575  1100 l           Plast              Dúbravka       Bratislava 4
# 90576  1100 l           Plech               Rusovce       Bratislava 5
#
#            KU - ulice KU - číslo orientační                 Název stanoviště  \
# ...

# %%
# Out:
#   File "<ipython-input-11-63fead56fa7c>", line 1
#     curl https://maps.googleapis.com/maps/api/geocode/json?address=Kôstková30,Bratislava+CA&key=AIzaSyCp5_r8YXqn1XFa589X1hpumAogDcJ7I4Q
#          ^
# SyntaxError: invalid syntax
